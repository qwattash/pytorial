# %% [markdown]
# # Introduction
# This is my first attempt to create a python tutorial. It is primarily aimed towards using python for data visualization purposes.
# The first few sections will introduce the basic features of the language along with basic exericises. I will attempt to introduce interesting examples as soon as possible in order to keep the textbook feeling at a minimum.
# This tutorial is aimed to someone with no programming background, so it will explain also terms and concepts that are obvious to those with programming experience.
#
# ## Table of contents
# 1. [**What is python and how do I get it?**](install.ipynb)
# 2. [**Language features**](lang.ipynb)
# 3. **Less basic stuff**
#   - Control flow v2
#   - Reusing your code v2

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

plt.plot([1, 2, 3, 4])
plt.ylabel("Some Numbers")
plt.show()
